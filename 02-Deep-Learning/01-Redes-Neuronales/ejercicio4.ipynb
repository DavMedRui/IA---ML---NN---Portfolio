# %%
import numpy as np

# %%
tasa = 0.5
entradas = [0, 5, 10]
salidas = [32, 41, 50]

# %%
def neurona (tasa, entradas, salidas):
    pesos = 100
    resultados = []
    
    for e, s in zip(entradas, salidas):
        for j in range(0, pesos):
