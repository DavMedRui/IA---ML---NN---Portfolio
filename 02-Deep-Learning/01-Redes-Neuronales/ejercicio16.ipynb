# %%
#Cargamos el modelo del ejercicio 15
from keras.models import load_model

red = load_model("red.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#Creamos arrays con los datos nuevos y convertimos las imágenes a escala de grises y arrays
import numpy as np
import matplotlib.pyplot as plt

img = plt.imread("nueve.png")
plt.figure(figsize=(3,3))
plt.gray()
plt.imshow(img)

# %%
red.summary()
# Out:
# Model: "miguel_ange"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1600)           │     1,256,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │        16,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,272,012 (4.85 MB)
#  Trainable params: 1,272,010 (4.85 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(red, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
X = np.array([img])
X = X.reshape(1,28*28)

# %%
pred = red.predict(X)
pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# array([[1.2465218e-09, 2.0620148e-01, 7.9875337e-03, 3.7597260e-01,
#         5.2374879e-11, 1.0340462e-08, 1.7898346e-04, 3.5466913e-02,
#         3.7419251e-01, 9.5300745e-10]], dtype=float32)

# %%
digito = np.argmax(pred)
print("Es un", digito)
# Out:
# Es un 3
