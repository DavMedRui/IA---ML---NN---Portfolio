# %%
#Cargamos el modelo del ejercicio 15
from keras.models import load_model

red = load_model("mnist_conv.keras")

# %%
#Creamos arrays con los datos nuevos y convertimos las imágenes a escala de grises y arrays
import numpy as np
import matplotlib.pyplot as plt

img = plt.imread("uno.png")
plt.figure(figsize=(3,3))
plt.gray()
plt.imshow(img)

# %%
red.summary()
# Out:
# Model: "numeros"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ convolucion_1 (Conv2D)          │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pooling (MaxPooling2D)          │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     2,049,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │        10,010 │
# ...

# %%
from tensorflow.keras.utils import plot_model
plot_model(red, show_shapes=True)

# %%
X = np.array([img])
X = X.reshape(1,28,28,1)

# %%
pred = red.predict(X)
pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# array([[1.8144590e-05, 9.7215110e-01, 1.3930953e-02, 3.7643393e-05,
#         1.0520596e-02, 9.2353897e-05, 3.4190324e-04, 9.7774820e-05,
#         1.1466368e-03, 1.6628798e-03]], dtype=float32)

# %%
digito = np.argmax(pred)
print("Es un", digito)
# Out:
# Es un 1
